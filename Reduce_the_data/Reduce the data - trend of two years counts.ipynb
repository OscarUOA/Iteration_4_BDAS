# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Reduce_the_data_trend_two_years_counts').getOrCreate()

df = spark.read.csv('../Bike-Sharing-Dataset-hour_new.csv',header=True,inferSchema=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

group_df = df.toPandas()
x = group_df["reinstant"]
y = group_df["cnt"]
plt.bar(x, y, color='r')

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), "r--", color='b')

plt.legend(['trnedline','cnt'])
plt.xlabel('reinstant')
plt.ylabel('counts')
plt.title('trend for two years counts')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,8)

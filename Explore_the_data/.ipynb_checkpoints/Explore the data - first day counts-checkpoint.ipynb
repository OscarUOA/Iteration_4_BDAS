# %%
import pandas
data = pandas.read_csv("../Bike-Sharing-Dataset-hour.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

day = data["instant"][0:23]
casual = data["casual"][0:23]
registered = data["registered"][0:23]
cnt = data["cnt"][0:23]

plt.plot(day, cnt, color = 'r')
plt.plot(day, registered, color = 'y')
plt.plot(day, casual, color = 'b')
plt.xlabel('first day')
plt.ylabel('counts')
plt.legend(['cnt', 'registered', 'casual'])
plt.title('first day counts')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,5)

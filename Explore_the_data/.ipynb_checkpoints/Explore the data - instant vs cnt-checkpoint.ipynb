# %%
import pandas
data = pandas.read_csv("../Bike-Sharing-Dataset-hour.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.bar(data["instant"], data["cnt"])
plt.xlabel('instant')
plt.ylabel('cnt')
plt.title('instant vs cnt')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,10)

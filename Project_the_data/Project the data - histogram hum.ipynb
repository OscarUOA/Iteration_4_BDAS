# %%
import pandas

data = pandas.read_csv("../Bike-Sharing-Dataset-hour_new.csv")

import matplotlib.pyplot as plt

plt.hist(data["hum"], 50)
plt.title('hum Histogram')

plt.show()

# %%
plt.rcParams['figure.figsize'] = (10,5)

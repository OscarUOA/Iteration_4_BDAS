# %%
import pandas

data = pandas.read_csv("../Bike-Sharing-Dataset-hour_new.csv")

import matplotlib.pyplot as plt
import numpy as np

np.log(data['cnt']).plot.hist(bins=50)
plt.title('cnt Logarithm')
plt.ylabel('')

plt.show()

# %%
plt.rcParams['figure.figsize'] = (10,5)
